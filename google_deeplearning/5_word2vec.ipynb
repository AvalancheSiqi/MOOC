# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_sg_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_sg_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_sg_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 5000 == 0:
      if step > 0:
        average_loss = average_loss / 5000
      # The average loss is an estimate of the loss over the last 5000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  sg_final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.050043
# Nearest to many: already, dystopian, developed, kindred, sforza, naturally, asymptotes, inform,
# Nearest to world: vertebrae, hopeful, plummeted, destroys, allergic, stripping, modernisation, anaesthetic,
# Nearest to more: idleness, illuminati, bolivar, tabby, zapotec, sukkot, riso, herc,
# Nearest to its: morningside, pyramidal, curse, melcher, coca, strategies, excerpt, cruiser,
# Nearest to this: seinfeld, bounced, resale, stupor, demonolatry, entrepreneurial, peacock, combatants,
# Nearest to history: spalding, silicone, silver, oed, labeled, hellenic, cystic, unregistered,
# Nearest to i: lyndon, punts, annulment, francophone, entitled, mallets, laodicea, loved,
# Nearest to used: agade, chuang, disappointment, imagery, popping, chatter, quixote, slovenians,
# Nearest to however: eccentricities, gareth, ehr, jeddah, eisenman, besieging, siegfried, pastures,
# Nearest to american: macaulay, basis, macromolecule, least, hellenes, pitted, kassites, humility,
# Nearest to when: ambivalent, postmodernist, muster, brahmin, democrat, delle, thessalonica, lessens,
# Nearest to may: blitz, polg, normale, returning, queen, enrollments, hooking, resonated,
# Nearest to been: biya, seized, taxpayer, pfaff, tagore, chop, nepeta, ges,
# Nearest to known: ortho, extras, listerine, tinymud, emails, sleep, goldman, chan,
# Nearest to b: platoon, positive, breasts, centrum, squad, councils, shimizu, tap,
# Nearest to often: yemeni, ousted, utamaro, flats, jeffreys, paperback, digital, tenuous,
# Average loss at step 5000: 4.038266
# Average loss at step 10000: 3.681816
# Average loss at step 15000: 3.557505
# Average loss at step 20000: 3.475451
# Nearest to many: some, several, these, all, other, various, already, most,
# Nearest to world: berzelius, comore, cortez, coro, slowed, prevalent, disallow, brent,
# Nearest to more: less, rather, most, tabby, drink, sae, cenozoic, cathar,
# Nearest to its: their, his, the, assay, some, pyramidal, her, encamped,
# Nearest to this: it, which, the, agilent, that, a, directly, subscribe,
# Nearest to history: spalding, physics, character, styles, silver, actinium, through, silicone,
# Nearest to i: ii, we, iii, jogging, grips, cruise, democide, entropic,
# Nearest to used: paralysis, known, agade, found, chatter, helm, occultism, charley,
# Nearest to however: but, then, perpetuation, that, gave, bactrian, besieging, gerardus,
# Nearest to american: macaulay, kitt, and, basis, mulligan, raj, british, octavio,
# Nearest to when: if, after, until, where, was, restraining, without, ceres,
# Nearest to may: can, would, will, could, might, to, imr, should,
# Nearest to been: be, become, was, isotope, never, biya, being, darwinism,
# Nearest to known: well, used, such, fallen, avowed, frequently, choruses, scheduled,
# Nearest to b: d, pros, ullman, tranquility, footballer, oak, vowels, soup,
# Nearest to often: sometimes, still, also, who, tishri, usually, ousted, appalling,
# Average loss at step 25000: 3.489921
# Average loss at step 30000: 3.490777
# Average loss at step 35000: 3.495396
# Average loss at step 40000: 3.376840
# Nearest to many: some, several, these, various, those, all, most, patients,
# Nearest to world: comore, safeguards, coro, brent, destroys, insurrections, cortez, disallow,
# Nearest to more: less, most, rather, longer, cenozoic, tabby, very, saucers,
# Nearest to its: their, his, her, the, pyramidal, extremism, our, redshift,
# Nearest to this: which, it, the, that, agilent, pentateuch, some, any,
# Nearest to history: critical, silicone, sinclair, structure, particle, drivetrain, issues, invokes,
# Nearest to i: ii, we, he, t, she, you, iii, they,
# Nearest to used: known, found, available, sold, given, considered, described, referred,
# Nearest to however: but, that, while, perpetuation, though, then, since, although,
# Nearest to american: russian, english, british, australian, halmos, french, german, irish,
# Nearest to when: if, while, before, until, where, after, during, with,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Nearest to been: become, be, was, already, were, being, had, reef,
# Nearest to known: used, such, well, ebony, fallen, scheduled, avowed, xun,
# Nearest to b: d, stamford, c, oak, tranquility, footballer, ullman, esquerra,
# Nearest to often: sometimes, usually, still, also, who, widely, generally, frequently,
# Average loss at step 45000: 3.448631
# Average loss at step 50000: 3.382576
# Average loss at step 55000: 3.432334
# Average loss at step 60000: 3.404165
# Nearest to many: some, several, various, these, both, all, most, those,
# Nearest to world: comore, largest, interiors, meconium, vietnam, confessional, slowed, laing,
# Nearest to more: less, rather, longer, very, most, cenozoic, smaller, greater,
# Nearest to its: their, his, the, her, our, extremism, sat, aberfoyle,
# Nearest to this: which, it, that, there, the, some, agilent, policeman,
# Nearest to history: geography, list, basque, callisthenes, particle, silicone, critical, structure,
# Nearest to i: ii, we, you, t, iii, they, democide, g,
# Nearest to used: known, sold, available, described, written, found, cited, seen,
# Nearest to however: but, although, though, that, which, when, while, perpetuation,
# Nearest to american: english, russian, irish, international, australian, guelfs, british, italian,
# Nearest to when: if, while, before, although, where, after, until, because,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to been: become, be, already, was, had, were, reef, being,
# Nearest to known: used, such, well, ebony, called, considered, described, scheduled,
# Nearest to b: d, c, f, timeframe, r, oak, deviates, beset,
# Nearest to often: usually, sometimes, still, also, generally, commonly, frequently, now,
# Average loss at step 65000: 3.284127
# Average loss at step 70000: 3.378047
# Average loss at step 75000: 3.356485
# Average loss at step 80000: 3.353407
# Nearest to many: some, several, various, these, most, those, both, all,
# Nearest to world: comore, u, cortez, mistreatment, interiors, dewan, gondor, labouring,
# Nearest to more: less, very, rather, most, longer, higher, quite, larger,
# Nearest to its: their, his, her, our, the, extremism, redshift, minefields,
# Nearest to this: which, it, mas, the, another, instructional, agilent, itself,
# Nearest to history: list, skinned, geography, callisthenes, britannica, natives, sinclair, relational,
# Nearest to i: ii, you, we, iii, g, und, aman, democide,
# Nearest to used: known, available, sold, referred, seen, written, found, cited,
# Nearest to however: but, although, though, that, while, perpetuation, where, thus,
# Nearest to american: russian, irish, canadian, british, international, halmos, german, italian,
# Nearest to when: if, before, after, while, though, where, because, during,
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Nearest to been: become, be, was, already, previously, being, were, rockies,
# Nearest to known: used, called, classified, ebony, described, such, considered, defined,
# Nearest to b: d, f, c, timeframe, r, builders, vitamin, canetti,
# Nearest to often: usually, sometimes, generally, commonly, still, now, typically, frequently,
# Average loss at step 85000: 3.409089
# Average loss at step 90000: 3.362042
# Average loss at step 95000: 3.326549
# Average loss at step 100000: 3.314959
# Nearest to many: several, some, various, these, all, few, those, numerous,
# Nearest to world: universe, comore, dewan, mistreatment, laing, country, labouring, rh,
# Nearest to more: less, most, very, rather, longer, quite, greater, larger,
# Nearest to its: their, his, her, the, our, pyramidal, extremism, cosmetic,
# Nearest to this: which, it, the, another, judaeo, he, itself, that,
# Nearest to history: list, skinned, callisthenes, giga, geography, zoroastrianism, feodor, historical,
# Nearest to i: ii, we, you, iii, they, anaesthetic, ramone, t,
# Nearest to used: sold, available, known, found, applied, designed, referred, cited,
# Nearest to however: but, although, though, that, slovenians, there, while, where,
# Nearest to american: british, italian, canadian, babcock, irish, russian, australian, japanese,
# Nearest to when: if, before, while, where, although, though, because, after,
# Nearest to may: could, can, would, might, must, should, will, cannot,
# Nearest to been: become, be, already, recently, was, previously, wawel, were,
# Nearest to known: used, described, such, ebony, possible, called, defined, classified,
# Nearest to b: d, oak, c, thompson, computability, psi, brackets, imt,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, actually, still,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
words = [reverse_dictionary[i] for i in range(1, num_points+1)]

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

# %%
sg_two_d_embeddings = tsne.fit_transform(sg_final_embeddings[1:num_points+1, :])
plot(sg_two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Function to generate a training batch for the CBOW model, use C=4.

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    batch_tmp = np.ndarray(shape=(num_skips), dtype=np.int32)
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch_tmp[j] = buffer[target]
    batch[i] = batch_tmp
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[vi] for vi in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['as', 'anarchism'], ['a', 'originated'], ['term', 'as'], ['a', 'of'], ['abuse', 'term'], ['first', 'of'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['term', 'anarchism', 'a', 'originated'], ['originated', 'as', 'term', 'of'], ['a', 'as', 'abuse', 'of'], ['term', 'first', 'abuse', 'a'], ['of', 'term', 'used', 'first'], ['used', 'of', 'abuse', 'against'], ['against', 'abuse', 'first', 'early'], ['early', 'first', 'used', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Train a CBOW model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = None
  for i in xrange(num_skips):
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:, i])
    emb_x, emb_y = embedding_i.get_shape().as_list()
    if embeds is None:
      embeds = tf.reshape(embedding_i, [emb_x, emb_y, 1])
    else:
      embeds = tf.concat(2, [embeds, tf.reshape(embedding_i, [emb_x, emb_y, 1])])

  avg_embed = tf.reduce_mean(embeds, 2, keep_dims=False)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 5000 == 0:
      if step > 0:
        average_loss = average_loss / 5000
      # The average loss is an estimate of the loss over the last 5000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  cbow_final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.944626
# Nearest to states: implicit, ownership, cartwright, advisor, existence, storytelling, vanilla, oliver,
# Nearest to also: gnumeric, complicity, simone, bubba, greenaway, overwhelm, sorbonne, resettle,
# Nearest to some: claus, unknowns, shunned, tychonoff, demille, atlas, vrml, laguna,
# Nearest to five: biro, expressive, ferdinand, want, finale, boredom, montevideo, channels,
# Nearest to an: warming, flagella, mayors, bland, mormonism, pacing, dip, suing,
# Nearest to the: ladyland, assembled, xiaoping, dwell, fay, moli, highness, dlr,
# Nearest to who: rhodes, roused, hutton, wonderswan, forming, claude, crannog, communicative,
# Nearest to state: chemotherapy, linda, asexually, delian, phosphorylation, lal, oxide, leppard,
# Nearest to years: perdition, ts, pwn, unam, pretence, forl, antikythera, edd,
# Nearest to so: bromide, shaikh, bloodline, enron, payoff, pinky, drawing, hose,
# Nearest to other: shores, timeout, yitzhak, deptford, morphine, restraining, relay, gabor,
# Nearest to it: sorrows, mandatory, degrees, dyeing, approximating, lenoir, mckinley, campos,
# Nearest to used: marbles, patrilineal, rosicrucian, gazpacho, eamonn, synchronization, bloodiest, drowned,
# Nearest to see: leith, colourful, addis, thyestes, niches, gifs, screenplay, discreetly,
# Nearest to nine: serra, facility, pauses, disinformation, rimini, gate, spared, universalists,
# Nearest to were: crucifix, qc, dom, disturbs, atreides, looksmart, typographical, glycolipids,
# Average loss at step 5000: 3.791893
# Average loss at step 10000: 3.330170
# Average loss at step 15000: 3.291205
# Average loss at step 20000: 3.213694
# Nearest to states: kingdom, implicit, vor, arabella, monsanto, quetzalcoatl, existence, cartwright,
# Nearest to also: gnumeric, cancel, southwards, now, bust, boasting, complicity, absurdist,
# Nearest to some: many, these, most, all, upward, various, any, macroevolution,
# Nearest to five: six, eight, seven, four, three, zero, nine, renounced,
# Nearest to an: suing, graced, einsatzgruppen, protista, newline, dip, particulate, prescient,
# Nearest to the: its, a, their, another, moli, his, any, relayed,
# Nearest to who: contenders, he, tesla, mujibur, crewmembers, fujian, archipelagoes, compressors,
# Nearest to state: lal, enact, chemotherapy, elegantly, band, eastern, kr, religion,
# Nearest to years: perdition, changes, pretence, burrell, observed, radii, decades, viennese,
# Nearest to so: shaikh, notional, kitten, edsel, hose, arg, sometimes, carangi,
# Nearest to other: shores, relay, various, simmons, these, testes, morphine, guides,
# Nearest to it: he, this, degrees, approximating, actually, something, deformities, there,
# Nearest to used: found, marbles, axel, bloodiest, described, rococo, known, employed,
# Nearest to see: sw, dependency, thyestes, discreetly, refutations, addis, soteriology, inbound,
# Nearest to nine: eight, seven, zero, five, billion, six, late, october,
# Nearest to were: are, was, flyers, have, became, had, is, be,
# Average loss at step 25000: 3.181701
# Average loss at step 30000: 3.155947
# Average loss at step 35000: 3.051558
# Average loss at step 40000: 3.075266
# Nearest to states: kingdom, implicit, nations, glossy, congressional, outlaws, ablaze, quetzalcoatl,
# Nearest to also: now, below, never, chagrin, absurdist, gunship, sometimes, broken,
# Nearest to some: many, various, most, these, all, several, both, upward,
# Nearest to five: four, six, seven, eight, three, zero, two, priceless,
# Nearest to an: protista, dip, prescient, newline, suing, bland, logistics, particulate,
# Nearest to the: its, a, moli, another, your, fay, dyadic, each,
# Nearest to who: he, contenders, crewmembers, mujibur, archipelagoes, compressors, winnie, born,
# Nearest to state: henderson, elegantly, religion, enact, penguin, footprints, band, leppard,
# Nearest to years: decades, perdition, months, burrell, changes, days, pretence, year,
# Nearest to so: robson, endanger, arg, shaikh, sometimes, kitten, noted, uppermost,
# Nearest to other: various, testes, these, simmons, some, guides, mathias, shores,
# Nearest to it: he, this, she, degrees, beaver, there, fuel, approximating,
# Nearest to used: found, known, designed, employed, referred, marbles, bloodiest, described,
# Nearest to see: sw, inbound, thyestes, parc, includes, boadicea, rok, addis,
# Nearest to nine: eight, seven, six, late, five, octavian, february, neared,
# Nearest to were: are, was, had, have, became, be, exclaimed, been,
# Average loss at step 45000: 3.080784
# Average loss at step 50000: 3.014419
# Average loss at step 55000: 3.018738
# Average loss at step 60000: 2.954092
# Nearest to states: kingdom, nations, implicit, congressional, glossy, ablaze, outlaws, chameleon,
# Nearest to also: below, now, which, cytology, never, chagrin, absurdist, still,
# Nearest to some: many, most, various, several, all, both, these, upward,
# Nearest to five: four, seven, six, eight, three, zero, two, nine,
# Nearest to an: prescient, dip, another, protista, newline, suing, battista, mugwort,
# Nearest to the: oppositions, its, our, their, your, a, his, moli,
# Nearest to who: he, archipelagoes, crewmembers, contenders, winnie, compressors, freeview, tinged,
# Nearest to state: religion, complication, henderson, enact, overtraining, elegantly, leppard, source,
# Nearest to years: decades, months, days, burrell, perdition, year, pretence, stacking,
# Nearest to so: sometimes, unlikely, arg, uppermost, robson, endanger, azteca, objects,
# Nearest to other: various, testes, these, shores, pressuring, individual, guides, preparatory,
# Nearest to it: he, this, she, there, fuel, preview, beaver, approximating,
# Nearest to used: employed, designed, known, found, referred, available, called, blossom,
# Nearest to see: inbound, includes, sw, cycladic, protocols, banker, dauphin, diameters,
# Nearest to nine: eight, seven, six, late, five, zero, chapter, january,
# Nearest to were: are, was, had, have, became, be, rashid, exclaimed,
# Average loss at step 65000: 2.930263
# Average loss at step 70000: 2.901956
# Average loss at step 75000: 2.886942
# Average loss at step 80000: 2.909534
# Nearest to states: kingdom, nations, implicit, ablaze, congressional, glossy, outlaws, uniformly,
# Nearest to also: now, below, cytology, still, disambiguation, never, peterborough, mazzola,
# Nearest to some: many, most, various, several, both, all, coronado, macroevolution,
# Nearest to five: four, six, seven, three, eight, zero, thousand, two,
# Nearest to an: prescient, another, protista, dip, newline, bland, suing, mugwort,
# Nearest to the: our, your, its, another, dyadic, moli, their, cebus,
# Nearest to who: he, archipelagoes, crewmembers, contenders, winnie, compressors, mondial, freeview,
# Nearest to state: complication, elegantly, leppard, enact, government, religion, overtraining, henderson,
# Nearest to years: decades, months, days, year, burrell, pretence, perdition, minutes,
# Nearest to so: sometimes, unlikely, arg, uppermost, danforth, too, endanger, azteca,
# Nearest to other: various, testes, these, individual, pressuring, shores, preparatory, arlen,
# Nearest to it: he, she, this, there, fuel, preview, itself, beaver,
# Nearest to used: employed, designed, found, referred, known, available, regarded, seen,
# Nearest to see: includes, inbound, banker, sw, protocols, cycladic, but, determines,
# Nearest to nine: eight, seven, six, zero, late, denning, billion, october,
# Nearest to were: are, was, had, exclaimed, have, rashid, muggs, been,
# Average loss at step 85000: 2.900321
# Average loss at step 90000: 2.868994
# Average loss at step 95000: 2.862721
# Average loss at step 100000: 2.576950
# Nearest to states: kingdom, nations, glossy, congressional, ablaze, implicit, outlaws, chameleon,
# Nearest to also: now, below, still, never, disambiguation, which, cytology, often,
# Nearest to some: many, most, both, various, several, all, coronado, these,
# Nearest to five: four, six, three, seven, eight, zero, two, flipper,
# Nearest to an: prescient, another, protista, suing, nb, bland, newline, warnings,
# Nearest to the: our, your, its, their, pretending, arbuthnot, oppositions, silks,
# Nearest to who: he, crewmembers, compressors, archipelagoes, contenders, cohen, winnie, mondial,
# Nearest to state: complication, elegantly, overtraining, government, enact, henderson, source, leppard,
# Nearest to years: decades, months, days, year, burrell, minutes, weeks, pretence,
# Nearest to so: sometimes, too, unlikely, azteca, uppermost, cholesterol, daiko, feel,
# Nearest to other: various, testes, these, individual, guides, preparatory, including, pressuring,
# Nearest to it: he, she, this, there, anatoly, something, melanogaster, fuel,
# Nearest to used: designed, employed, referred, found, allowed, known, regarded, available,
# Nearest to see: includes, cycladic, but, called, inbound, diameters, banker, yolk,
# Nearest to nine: eight, seven, six, zero, june, january, february, october,
# Nearest to were: are, was, had, have, exclaimed, rashid, being, muggs,

# %%
cbow_two_d_embeddings = tsne.fit_transform(cbow_final_embeddings[1:num_points+1, :])
plot(cbow_two_d_embeddings, words)
